# %%
a = 10

if a==10:
    print("my name is jitendra")
# Out:
# my name is jitendra

# %%
a==10
# Out:
# True

# %%
a==11
# Out:
# False

# %%
a=10

if a==11:
    print("my name is jitendra")

# %%
age=19

if age >=18:
    print("you are eligible for voting")
# Out:
# you are eligible for voting

# %%
age=int(input("Enter your age: "))

if age >=18:
    print("you are eligible for voting")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 age=int(input("Enter your age: "))
#       3 if age >=18:
#       4     print("you are eligible for voting")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
age=16

if age >=18:
    print("you are eligible for voting")
else:
    print("you are not eligible for voting")
# Out:
# you are not eligible for voting

# %%
salary=21000

if salary <= 10000:
    print("you are eligible for normal credit card")
elif salary > 10000 and salary <= 20000:
    print("you are eligible for silver credit card")
elif salary > 20000 and salary <= 30000:
    print("you are eligible for gold credit card")
else:
    print("Need to check")
# Out:
# you are eligible for gold credit card
