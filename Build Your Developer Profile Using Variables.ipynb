# %% [markdown]
# # Create Python variables to store the following details

# %%
# Your name
# Age
# City
# College/company name
# Current learning topic
# Years of experience or study
# Whether you like Python (True/False)
# Your expected salary after learning Python
# Print every value.
# Then print the data type of every variable using type().

# %%
Your_name="Jitendra Kumar Kushwaha"

# %%
Age=33

# %%
City="Pune"

# %%
Company_name="LTM"

# %%
Current_learning_topic="Python"

# %%
Years_of_experience=11.0

# %%
Whether_you_like_Python=True

# %%
Your_expected_salary_after_learning_Python=400000.0

# %%
print(Your_name)
# Out:
# Jitendra Kumar Kushwaha

# %%
print(Age)
# Out:
# 33

# %%
print(City)
# Out:
# Pune

# %%
print(Company_name)
# Out:
# LTM

# %%
print(Current_learning_topic)
# Out:
# Python

# %%
print(Years_of_experience)
# Out:
# 11.0

# %%
print(Whether_you_like_Python)
# Out:
# True

# %%
print(Your_expected_salary_after_learning_Python)
# Out:
# 400000.0

# %%
print(type(Your_name))
# Out:
# <class 'str'>

# %%
print(type(Age))
# Out:
# <class 'int'>

# %%
print(type(City))
# Out:
# <class 'str'>

# %%
print(type(Company_name))
# Out:
# <class 'str'>

# %%
print(type(Current_learning_topic))
# Out:
# <class 'str'>

# %%
print(type(Years_of_experience))
# Out:
# <class 'float'>

# %%
print(type(Whether_you_like_Python))
# Out:
# <class 'bool'>

# %%
print(type(Your_expected_salary_after_learning_Python))
# Out:
# <class 'float'>
