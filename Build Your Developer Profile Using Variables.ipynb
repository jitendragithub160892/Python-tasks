# %% [markdown]
# # Create Python variables to store the following details

# %%
# Your name

name="Jitendra Kumar Kushwaha"

# Age

age=33

# City

city="Pune"

# College/company name

company_name="LTM"

# Current learning topic

current_learning_topic="Python"

# Years of experience or study

years_of_experience=11.0

# Whether you like Python (True/False)

whether_I_like_Python=True

# Your expected salary after learning Python

my_expected_salary_after_learning_Python=400000.0

# %% [markdown]
# # Print every value.

# %%
print(name)
# Out:
# Jitendra Kumar Kushwaha

# %%
print(age)
# Out:
# 33

# %%
print(city)
# Out:
# Pune

# %%
print(company_name)
# Out:
# LTM

# %%
print(current_learning_topic)
# Out:
# Python

# %%
print(years_of_experience)
# Out:
# 11.0

# %%
print(whether_I_like_Python)
# Out:
# True

# %%
print(my_expected_salary_after_learning_Python)
# Out:
# 400000.0

# %% [markdown]
# # Then print the data type of every variable using type().

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(city))
# Out:
# <class 'str'>

# %%
print(type(company_name))
# Out:
# <class 'str'>

# %%
print(type(current_learning_topic))
# Out:
# <class 'str'>

# %%
print(type(years_of_experience))
# Out:
# <class 'float'>

# %%
print(type(whether_I_like_Python))
# Out:
# <class 'bool'>

# %%
print(type(my_expected_salary_after_learning_Python))
# Out:
# <class 'float'>
