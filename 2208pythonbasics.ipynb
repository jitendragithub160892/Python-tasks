# %%
1+1
# Out:
# 2

# %%
False-True
# Out:
# -1

# %%
s="my name is jitendra"

# %%
len(s)
# Out:
# 19

# %%
a=10
b=45
c='jitendra'

# %%
a
# Out:
# 10

# %%
b
# Out:
# 45

# %%
c
# Out:
# 'jitendra'

# %%
a,b,c=10,45,'jitendra'

# %%
a
# Out:
# 10

# %%
b
# Out:
# 45

# %%
c
# Out:
# 'jitendra'

# %%
l=[3,4,5,6,7,'jitendra',56,67]

# %%
l[0]
# Out:
# 3

# %%
l[-8]
# Out:
# 3

# %%
l[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l[9]
#
# IndexError: list index out of range

# %%
l[-9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 l[-9]
#
# IndexError: list index out of range

# %%
l[0:3]
# Out:
# [3, 4, 5]

# %%
l=['euron',4,6,7,9,34.56,'jitendra']

# %%
l[0:7:2]
# Out:
# ['euron', 6, 9, 'jitendra']

# %%
l[0:70:2]
# Out:
# ['euron', 6, 9, 'jitendra']

# %%
l[0:5:-1]
# Out:
# []

# %%
s='jitendra'

# %%
l=[1,2,3,4,5]

# %%
tuple(l)
# Out:
# (1, 2, 3, 4, 5)

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l.extend((9,8,7))

# %%
l
# Out:
# [1, 2, 3, 4, 5, 9, 8, 7]

# %%
l.extend(34)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 l.extend(34)
#
# TypeError: 'int' object is not iterable
