# %% [markdown]
# # Your machine should have

# %%
# Python installed
# Correct Python version verified
# python --version / equivalent command working

import sys
print(sys.version)
# Out:
# 3.13.15 (v3.13.15:4061bc4c35f, Aug  5 2026, 09:08:51) [Clang 21.0.0 (clang-2100.1.1.101)]

# %%
# pip working

# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# VS Code installed
#
# Python extension configured
#
# Project folder created
#
# Python file created

# %%
# First Python program executed successfully

print("Hello")
# Out:
# Hello

# %%
# Virtual environment created and activated

# python3 -m venv myenv
# source myenv/bin/activate

# Package installation tested

import pandas as pd

# Demonstrate It

# During the YouTube video, show your actual setup.

# %% [markdown]
# # Create and execute a simple program such as

# %%
name = input("Enter your name: ")

print(f"Hello {name}, my Super30 environment is ready!")

# Show that the program executes successfully from your VS Code environment.
# Out:
# Hello Ayush, my Super30 environment is ready!
