# %% [markdown]
# # Create this string

# %% [markdown]
# message = "   Welcome To Python Programming Class   "

# %% [markdown]
# # Use string methods to

# %%
# Remove extra spaces
message=message.strip()

# %%
message
# Out:
# 'Welcome To Python Programming Class'

# %%
# Convert everything to lowercase

message.lower()
# Out:
# 'welcome to python programming class'

# %%
# Convert everything to uppercase

message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING CLASS'

# %%
# Convert to title case

message.title()
# Out:
# 'Welcome To Python Programming Class'

# %%
# Replace "Python" with "Advanced Python"

message.replace("Python" , "Advanced Python")
# Out:
# 'Welcome To Advanced Python Programming Class'

# %%
# Check whether the string starts with "Welcome"

message.startswith("Welcome")
# Out:
# True

# %%
# Check whether it ends with "Class"

message.endswith("Class")
# Out:
# True

# %%
# Count occurrences of "o"

message.count("o")
# Out:
# 4

# %%
# Find the position of "Programming"

message.find("Programming")
# Out:
# 18

# %%
message.index("Programming")
# Out:
# 18

# %%
# Split the sentence into words

message.split(" ")
# Out:
# ['Welcome', 'To', 'Python', 'Programming', 'Class']

# %% [markdown]
# # Must explain the difference between
# strip()
# lower()
# upper()
# title()
# replace()
# find()
# count()
# split()

# %% [markdown]
# strip(): Removes the leading and tailing white spaces.
# lower(): Covert all charater in lower case
# upper(): Covert all charater in upper case
# title(): Convert first character of each word capital/upper case.
# replace(): Replace old value to new value
# find(): Find the first occurance of string/substring
# count(): Count the occurances of string/substring
# split(): Split the string/sentence into list of substring based on given seperator
