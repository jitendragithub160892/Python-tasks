# %%
s = "euron systems"

# %%
type(s)
# Out:
# str

# %%
s.upper()
# Out:
# 'EURON SYSTEMS'

# %%
s.lower()
# Out:
# 'euron systems'

# %%
s.capitalize()
# Out:
# 'Euron systems'

# %%
# count of string/substring
s.count('e')
# Out:
# 2

# %%
s.count('eu')
# Out:
# 1

# %%
# index of first occurrence of string/substring
s.find('u')
# Out:
# 1

# %%
s.find('e')
# Out:
# 0

# %%
s.index('e')
# Out:
# 0

# %%
s.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s.index('z')
#
# ValueError: substring not found

# %%
s.find('z')
# Out:
# -1

# %%
s.split(' ')
# Out:
# ['euron', 'systems']

# %%
s.split()
# Out:
# ['euron', 'systems']

# %%
l=[1, 2, 3, 4, 5,6,'jitu']

# %%
l.append("kumar")

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 'jitu', 'kumar']

# %%
l.append([1,2,3])

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 'jitu', 'kumar', [1, 2, 3]]

# %%
l.extend("kushwaha")

# %%
l
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  'jitu',
#  'kumar',
#  [1, 2, 3],
#  'k',
#  'u',
#  's',
#  'h',
#  'w',
#  'a',
#  'h',
#  'a']

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 'jitu']

# %%
l.insert(2, (3,4,56))

# %%
l
# Out:
# [1, 2, (3, 4, 56), 3, 4, 5, 6, 'jitu']

# %%
# remove data from list
l.pop()
# Out:
# 'jitu'

# %%
l
# Out:
# [1, 2, (3, 4, 56), 3, 4, 5, 6]

# %%
l.pop(1)
# Out:
# 2

# %%
l
# Out:
# [1, (3, 4, 56), 3, 4, 5, 6]

# %%
l.pop(9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 l.pop(9)
#
# IndexError: pop index out of range

# %%
# remove value not index
l.remove(3)

# %%
l
# Out:
# [1, (3, 4, 56), 4, 5, 6]

# %%
l.count(1)
# Out:
# 1

# %%
l.reverse()

# %%
l
# Out:
# [6, 5, 4, (3, 4, 56), 1]

# %%
#reassign value
l[0]="jitu"

# %%
l
# Out:
# ['jitu', 5, 4, (3, 4, 56), 1]

# %%
l=[3,4,5,6,True]

# %%
#deep copy
l1=l.copy()

# %%
l1
# Out:
# [3, 4, 5, 6, True]

# %%
#shallow copy
l2=l.copy()

# %%
l
# Out:
# [3, 4, 5, 6, True]

# %%
l1
# Out:
# [3, 4, 5, 6, True]

# %%
l2
# Out:
# [3, 4, 5, 6, True]

# %%
l
# Out:
# [3, 4, 5, 6, True]

# %%
l[0]="Jitendra"

# %%
l
# Out:
# ['Jitendra', 4, 5, 6, True]

# %%
l1
# Out:
# ['Jitendra', 4, 5, 6, True]

# %%
l2
# Out:
# [3, 4, 5, 6, True]

# %%
l2[0]="Kumar"

# %%
l2
# Out:
# ['Kumar', 4, 5, 6, True]

# %%
l
# Out:
# ['Jitendra', 4, 5, 6, True]

# %%
l1
# Out:
# ['Jitendra', 4, 5, 6, True]

# %%
t=(3,4,5,6,7,"jitu")

# %%
t.count(3)
# Out:
# 1

# %%
#index of very first element    
t.index(3)
# Out:
# 0

# %%
t[0]
# Out:
# 3

# %%
t[0]="Kumar"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 t[0]="Kumar"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#List is mutable, meaning you can change its content (add, remove, or modify elements). Tuples, on the other hand, are immutable, meaning once they are created, their content cannot be changed.

# %%
s="jitu"

# %%
s[0]
# Out:
# 'j'

# %%
s[0]="x"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 s[0]="x"
#
# TypeError: 'str' object does not support item assignment

# %%
#Technically string is also immutable, meaning once they are created, their content cannot be changed.

# %%
#set
s={}

# %%
#not set it will be dict
type(s)
# Out:
# dict

# %%
s={2,3,2,3,4,5,3,3,4,5,6,4,3,5,6}

# %%
s
# Out:
# {2, 3, 4, 5, 6}

# %%
#set give unordered unique values, it will not give duplicate values and it will not maintain the order of insertion
s={2,3,2,3,4,5,3,3,4,5,6,4,3,5,6,"jitu",234,234.76,"kumar"}

# %%
s
# Out:
# {2, 234, 234.76, 3, 4, 5, 6, 'jitu', 'kumar'}

# %%
s={2,3,2,3,4,5,3,3,4,5,6,4,3,5,6,"jitu",234,234.76,"kumar","Python","python"}

# %%
s
# Out:
# {2, 234, 234.76, 3, 4, 5, 6, 'Python', 'jitu', 'kumar', 'python'}

# %%
s.add(2)

# %%
s
# Out:
# {2, 234, 234.76, 3, 4, 5, 6, 'Python', 'jitu', 'kumar', 'python'}

# %%
s.add(1234)

# %%
s
# Out:
# {1234, 2, 234, 234.76, 3, 4, 5, 6, 'Python', 'jitu', 'kumar', 'python'}

# %%
s1=s.copy()

# %%
s1
# Out:
# {1234, 2, 234, 234.76, 3, 4, 5, 6, 'Python', 'jitu', 'kumar', 'python'}

# %%
s.discard(2)

# %%
s
# Out:
# {1234, 234, 234.76, 3, 4, 5, 6, 'Python', 'jitu', 'kumar', 'python'}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s1.pop()
# Out:
# 2

# %%
d={"name":"John", "age":30, "city":"New York"}

# %%
d
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York'}

# %%
d={"name":"John", "age":30, "city":"New York", "name":"Kumar"}

# %%
d
# Out:
# {'name': 'Kumar', 'age': 30, 'city': 'New York'}

# %%
d={1234:"Jitu"}

# %%
d={#:123}
# Out:
#   Cell In[156], line 1
#     d={#:123}
#              ^
# SyntaxError: incomplete input

# %%
d={[1,2,4]:1123}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 d={[1,2,4]:1123}
#
# TypeError: unhashable type: 'list'

# %%
d={(1,2,4):123455}

# %%
d={{1:2}:1223}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 d={{1:2}:1223}
#
# TypeError: unhashable type: 'dict'

# %%
d={"name":"John", "age":30, "city":"New York", "country":"USA"}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'city', 'country'])

# %%
d.values()
# Out:
# dict_values(['John', 30, 'New York', 'USA'])

# %%
d.items()
# Out:
# dict_items([('name', 'John'), ('age', 30), ('city', 'New York'), ('country', 'USA')])

# %%
d['name']
# Out:
# 'John'

# %%
d['country']
# Out:
# 'USA'

# %%
d['courses']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 d['courses']
#
# KeyError: 'courses'

# %%
d['courses']=[ "Math", "Science", "English" ]

# %%
d
# Out:
# {'name': 'John',
#  'age': 30,
#  'city': 'New York',
#  'country': 'USA',
#  'courses': ['Math', 'Science', 'English']}

# %%
# add a key like address with value will be dict  
d['address']={'street': '123 Main St', 'city': 'New York', 'state': 'NY', 'zip': '10001'}

# %%
d
# Out:
# {'name': 'John',
#  'age': 30,
#  'city': 'New York',
#  'country': 'USA',
#  'courses': ['Math', 'Science', 'English'],
#  'address': {'street': '123 Main St',
#   'city': 'New York',
#   'state': 'NY',
#   'zip': '10001'}}

# %%
d['address']['zip']
# Out:
# '10001'

# %%
d['courses'][1]
# Out:
# 'Science'

# %%
d.pop('age')
# Out:
# 30

# %%
d
# Out:
# {'name': 'John',
#  'city': 'New York',
#  'country': 'USA',
#  'courses': ['Math', 'Science', 'English'],
#  'address': {'street': '123 Main St',
#   'city': 'New York',
#   'state': 'NY',
#   'zip': '10001'}}
