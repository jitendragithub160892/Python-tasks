# %% [markdown]
# # Create

# %%
employee = {

"name": "Amit",

"department": "Engineering",

"skills": {

"language": "Python",

"database": "PostgreSQL",

"cloud": "AWS"

},

"salary": 80000

}

# %% [markdown]
# # Without using loops

# %%
# Print employee name

print(employee['name'])

# Print department

print(employee['department'])

# Print complete skills dictionary

print(employee['skills'])

# Print programming language

print(employee['skills']['language'])

# Print database

print(employee['skills']['database'])

# Print cloud technology

print(employee['skills']['cloud'])

# Change "Python" to "Python + JavaScript"

employee['skills']['language']="Python + JavaScript"
print(employee)

# Change salary

employee['salary']=9000
print(employee)

# Add "experience": 3

employee['experience']=3
print(employee)

# Add another skill under the skills dictionary

employee['skills']['tool']="VScode"
print(employee)
# Out:
# Amit
# Engineering
# {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}
# Python
# PostgreSQL
# AWS
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 80000}
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 9000}
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 9000, 'experience': 3}
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'tool': 'VScode'}, 'salary': 9000, 'experience': 3}

# %% [markdown]
# #Explain how nested dictionaries are accessed
#
# We can access nested dictionaries by key, to access the value of inner dictionaries we first extract the inner dictionary by their key and after that we give the inner dictionary key to fetch the value of that key
